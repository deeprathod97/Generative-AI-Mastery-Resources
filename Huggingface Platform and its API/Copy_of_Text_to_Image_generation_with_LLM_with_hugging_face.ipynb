# %% [markdown]
# ## Text-to-Image Generation using Stable Diffusion and Diffusers

# %%
#diffusers is a hugging face page for using diffusion models from huggingface hub
# !pip install diffusers transformers accelerate
# Out:
# Collecting diffusers
#   Downloading diffusers-0.31.0-py3-none-any.whl.metadata (18 kB)
# Collecting transformers
#   Downloading transformers-4.46.0-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: accelerate in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.32.1)
# Requirement already satisfied: importlib-metadata in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (7.1.0)
# Requirement already satisfied: filelock in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (3.14.0)
# Requirement already satisfied: huggingface-hub>=0.23.2 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (0.23.3)
# Requirement already satisfied: numpy in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (2024.5.15)
# Requirement already satisfied: requests in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (0.4.3)
# Requirement already satisfied: Pillow in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (10.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (0.20.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: psutil in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from accelerate) (6.0.0)
# Requirement already satisfied: torch>=1.10.0 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from accelerate) (2.3.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub>=0.23.2->diffusers) (2024.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub>=0.23.2->diffusers) (4.12.0)
# Requirement already satisfied: sympy in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.10.0->accelerate) (1.12.1)
# Requirement already satisfied: networkx in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.10.0->accelerate) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from importlib-metadata->diffusers) (3.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->diffusers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->diffusers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->diffusers) (2024.2.2)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->accelerate) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->accelerate) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading diffusers-0.31.0-py3-none-any.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.9 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.9 MB 1.1 MB/s eta 0:00:03
#    ------- -------------------------------- 0.5/2.9 MB 1.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 0.8/2.9 MB 1.0 MB/s eta 0:00:03
#    -------------- ------------------------- 1.0/2.9 MB 967.3 kB/s eta 0:00:02
#    -------------- ------------------------- 1.0/2.9 MB 967.3 kB/s eta 0:00:02
#    ------------------ --------------------- 1.3/2.9 MB 780.2 kB/s eta 0:00:03
#    --------------------- ------------------ 1.6/2.9 MB 882.6 kB/s eta 0:00:02
#    ------------------------- -------------- 1.8/2.9 MB 898.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 2.1/2.9 MB 910.2 kB/s eta 0:00:01
#    ----------------------------- ---------- 2.1/2.9 MB 910.2 kB/s eta 0:00:01
#    -------------------------------- ------- 2.4/2.9 MB 906.7 kB/s eta 0:00:01
#    ------------------------------------ --- 2.6/2.9 MB 888.3 kB/s eta 0:00:01
#    ------------------------------------ --- 2.6/2.9 MB 888.3 kB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 888.8 kB/s eta 0:00:00
# Downloading transformers-4.46.0-py3-none-any.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.0 MB 452.8 kB/s eta 0:00:22
#    --- ------------------------------------ 0.8/10.0 MB 657.8 kB/s eta 0:00:15
#    --- ------------------------------------ 0.8/10.0 MB 657.8 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.0/10.0 MB 629.1 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.0/10.0 MB 629.1 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.3/10.0 MB 664.1 kB/s eta 0:00:14
#    ----- ---------------------------------- 1.3/10.0 MB 664.1 kB/s eta 0:00:14
#    ----- ---------------------------------- 1.3/10.0 MB 664.1 kB/s eta 0:00:14
#    ----- ---------------------------------- 1.3/10.0 MB 664.1 kB/s eta 0:00:14
#    ------ --------------------------------- 1.6/10.0 MB 534.1 kB/s eta 0:00:16
#    ------ --------------------------------- 1.6/10.0 MB 534.1 kB/s eta 0:00:16
#    ------ --------------------------------- 1.6/10.0 MB 534.1 kB/s eta 0:00:16
#    ------- -------------------------------- 1.8/10.0 MB 490.9 kB/s eta 0:00:17
#    ------- -------------------------------- 1.8/10.0 MB 490.9 kB/s eta 0:00:17
#    ------- -------------------------------- 1.8/10.0 MB 490.9 kB/s eta 0:00:17
#    -------- ------------------------------- 2.1/10.0 MB 487.3 kB/s eta 0:00:17
#    -------- ------------------------------- 2.1/10.0 MB 487.3 kB/s eta 0:00:17
#    --------- ------------------------------ 2.4/10.0 MB 486.2 kB/s eta 0:00:16
#    --------- ------------------------------ 2.4/10.0 MB 486.2 kB/s eta 0:00:16
#    ---------- -----------------------------
kB/s eta 0:00:07
#    ---------------------------- ----------- 7.1/10.0 MB 472.1 kB/s eta 0:00:07
#    ---------------------------- ----------- 7.1/10.0 MB 472.1 kB/s eta 0:00:07
#    ----------------------------- ---------- 7.3/10.0 MB 480.3 kB/s eta 0:00:06
#    ----------------------------- ---------- 7.3/10.0 MB 480.3 kB/s eta 0:00:06
#    ------------------------------ --------- 7.6/10.0 MB 483.3 kB/s eta 0:00:06
#    ------------------------------- -------- 7.9/10.0 MB 491.9 kB/s eta 0:00:05
#    ------------------------------- -------- 7.9/10.0 MB 491.9 kB/s eta 0:00:05
#    -------------------------------- ------- 8.1/10.0 MB 497.8 kB/s eta 0:00:04
#    --------------------------------- ------ 8.4/10.0 MB 504.4 kB/s eta 0:00:04
#    ---------------------------------- ----- 8.7/10.0 MB 511.8 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.9/10.0 MB 519.8 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.9/10.0 MB 519.8 kB/s eta 0:00:03
#    ------------------------------------ --- 9.2/10.0 MB 525.7 kB/s eta 0:00:02
#    ------------------------------------ --- 9.2/10.0 MB 525.7 kB/s eta 0:00:02
#    ------------------------------------- -- 9.4/10.0 MB 523.8 kB/s eta 0:00:02
#    ------------------------------------- -- 9.4/10.0 MB 523.8 kB/s eta 0:00:02
#    -------------------------------------- - 9.7/10.0 MB 529.8 kB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 536.1 kB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 536.4 kB/s eta 0:00:00
# Installing collected packages: diffusers, transformers
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\deepr\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\transformers\\models\\deprecated\\trajectory_transformer\\convert_trajectory_transformer_original_pytorch_checkpoint_to_pytorch.py'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths

# %%
from diffusers import StableDiffusionPipeline
import matplotlib.pyplot as plt
import torch

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.3.1
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: C:\Users\deepr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages
# Requires: filelock, fsspec, jinja2, mkl, networkx, sympy, typing-extensions
# Required-by: accelerate, detecto, torchaudio, torchmetrics, torchsde, torchvision, ultralytics, ultralytics-thop

# %%
# !pip install diffusers transformers torch
# Out:
# Requirement already satisfied: diffusers in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.31.0)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\deepr\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\transformers\\models\\deprecated\\trajectory_transformer\\convert_trajectory_transformer_original_pytorch_checkpoint_to_pytorch.py'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths
# Collecting transformers
#   Using cached transformers-4.46.0-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: torch in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.3.1)
# Requirement already satisfied: importlib-metadata in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (7.1.0)
# Requirement already satisfied: filelock in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (3.14.0)
# Requirement already satisfied: huggingface-hub>=0.23.2 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (0.23.3)
# Requirement already satisfied: numpy in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (2024.5.15)
# Requirement already satisfied: requests in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (0.4.3)
# Requirement already satisfied: Pillow in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from diffusers) (10.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (0.20.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (4.12.0)
# Requirement already satisfied: sympy in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (2024.6.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.12.0)
# Requirement already satisfied: colorama in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from importlib-metadata->diffusers) (3.18.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->diffusers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->diffusers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->diffusers) (2024.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\deepr\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy->torch) (1.3.0)
# Using cached transformers-4.46.0-py3-none-any.whl (10.0 MB)
# Installing collected packages: transformers

# %%
model_id1 = "dreamlike-art/dreamlike-diffusion-1.0"
model_id2 = "stabilityai/stable-diffusion-xl-base-1.0"

pipe = StableDiffusionPipeline.from_pretrained(model_id1, torch_dtype=torch.float16, use_safetensors=True)
pipe = pipe.to("cuda")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 4
#       1 model_id1 = "dreamlike-art/dreamlike-diffusion-1.0"
#       2 model_id2 = "stabilityai/stable-diffusion-xl-base-1.0"
# ----> 4 pipe = StableDiffusionPipeline.from_pretrained(model_id1, torch_dtype=torch.float16, use_safetensors=True)
#       5 pipe = pipe.to("cuda")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\diffusers\utils\dummy_torch_and_transformers_objects.py:1697, in StableDiffusionPipeline.from_pretrained(cls, *args, **kwargs)
#    1695 @classmethod
#    1696 def from_pretrained(cls, *args, **kwargs):
# -> 1697     requires_backends(cls, ["torch", "transformers"])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\diffusers\utils\import_utils.py:633, in requires_backends(obj, backends)
#     631 failed = [msg.format(name) for available, msg in checks if not available()]
#     632 if failed:
# --> 633     raise ImportError("".join(failed))
#     635 if name in [
#     636     "VersatileDiffusionTextToImagePipeline",
#     637     "VersatileDiffusionPipeline",
#    (...)
#     640     "UnCLIPPipeline",
#     641 ] and is_transformers_version("<", "4.25.0"):
#     642     raise ImportError(
#     643         f"You need to install `transformers>=4.25` in order to use {name}: \n```\n pip install"
#     644         " --upgrade transformers \n```"
#     645     )
#
# ImportError:
# StableDiffusionPipeline requires the transformers library but it was not found in your environment. You can install it with pip: `pip
# install transformers`

# %%
prompt = """dreamlikeart, a grungy woman with rainbow hair, travelling between dimensions, dynamic pose, happy, soft eyes and narrow chin,
extreme bokeh, dainty figure, long hair straight down, torn kawaii shirt and baggy jeans
"""

# %%
image = pipe(prompt).images[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 image = pipe(prompt).images[0]
#
# NameError: name 'pipe' is not defined

# %%
image
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 image
#
# NameError: name 'image' is not defined

# %%
print("[PROMPT]: ",prompt)
plt.imshow(image);
plt.axis('off');
# Out:
# [PROMPT]:  dreamlikeart, a grungy woman with rainbow hair, travelling between dimensions, dynamic pose, happy, soft eyes and narrow chin,
# extreme bokeh, dainty figure, long hair straight down, torn kawaii shirt and baggy jeans
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 print("[PROMPT]: ",prompt)
# ----> 2 plt.imshow(image);
#       3 plt.axis('off');
#
# NameError: name 'image' is not defined

# %%
prompt2 = """A girl is sittig on a chair & She is accompanied by her tiger. Make sure to keep it cinematic and color to be golden iris
"""

image = pipe(prompt2).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
print('[PROMPT]: ',prompt2)
plt.imshow(image);
plt.axis('off');
# Out:
# [PROMPT]:  A girl is sittig on a chair & She is accompanied by her tiger. Make sure to keep it cinematic and color to be golden iris

# %% [markdown]
# https://huggingface.co/docs/diffusers/using-diffusers/loading

# %% [markdown]
# ### Working with Stable Diffusion parameters
#
# * Negative prompting
# * num_inference_steps
# * height
# * weight
# * num_images_per_prompt

# %%
def generate_image(pipe, prompt, params):
  img = pipe(prompt, **params).images

  num_images = len(img)
  if num_images>1:
    fig, ax = plt.subplots(nrows=1, ncols=num_images)
    for i in range(num_images):
      ax[i].imshow(img[i]);
      ax[i].axis('off');

  else:
    fig = plt.figure()
    plt.imshow(img[0]);
    plt.axis('off');
  plt.tight_layout()

# %%
prompt = "dreamlike, beautiful girl playing the festival of colors, draped in traditional Indian attire, throwing colors"

params = {}

# %%
generate_image(pipe, prompt, params)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
#num inference steps
params = {'num_inference_steps': 100}

generate_image(pipe, prompt, params)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
#height width
params = {'num_inference_steps': 100, 'width': 512, 'height': int(1.5*640)}

generate_image(pipe, prompt, params)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
#num_images_per_prompt
params = {'num_inference_steps': 100, 'num_images_per_prompt': 2}

generate_image(pipe, prompt, params)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# negative_prompt
params = {'num_inference_steps': 100, 'num_images_per_prompt': 2, 'negative_prompt': 'ugly, distorted, low quality'}

generate_image(pipe, prompt, params)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
